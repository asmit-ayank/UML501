# %% [markdown]
# <a href="https://colab.research.google.com/github/asmit-ayank/UML501/blob/main/Assignment_4_updated_UML501.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4 Updated - Asmit Ayank (102497002)

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)

# %%
def generate_correlated_data(n_samples=500):
  base1 = np.random.randn(n_samples)
  base2 = np.random.randn(n_samples)
  X1 = base1 + np.random.randn(n_samples) * 0.3
  X2 = base1 + np.random.randn(n_samples) * 0.4
  X3 = 0.8 * base1 + 0.2 * base2 + np.random.randn(n_samples) * 0.3
  X4 = base2 + np.random.randn(n_samples) * 0.3
  X5 = base2 + np.random.randn(n_samples) * 0.35
  X6 = 0.6 * base1 + 0.4 * base2 + np.random.randn(n_samples) * 0.4
  X7 = 0.3 * base1 + 0.7 * base2 + np.random.randn(n_samples) * 0.35

  X = np.column_stack([X1, X2, X3, X4, X5, X6, X7])
  true_coefficients = np.array([3.5, -2.1, 1.8, 4.2, -1.5, 2.7, -3.0])
  y = X @ true_coefficients + np.random.randn(n_samples) * 2.0

  feature_names = [f'Feature_{i+1}' for i in range(7)]
  df = pd.DataFrame(X, columns=feature_names)
  df['Target'] = y
  return X, y, df, true_coefficients

# %%
generate_correlated_data(10)
# Out:
# (array([[ 0.93640878,  0.25603151,  0.52622776, -0.3661925 , -0.63112868,
#           0.25721966, -0.2522633 ],
#         [-0.20599719,  0.60264697, -0.15234691, -0.58125444, -0.5307104 ,
#           0.34596414, -0.24250072],
#         [ 0.667947  ,  0.64228965,  0.5318488 ,  0.03888567, -0.14525497,
#           0.47106762,  0.88094307],
#         [ 1.0956054 ,  1.09994548,  0.74543673, -1.72977736, -2.33195256,
#           0.77436328, -1.06378179],
#         [-0.39746819,  0.09486459, -0.97586286, -1.41561798, -1.44053379,
#          -1.8783572 , -1.56066126],
#         [-0.20086018, -0.72247442, -0.51572033, -0.28290349, -0.08760352,
#          -0.03663618, -0.63945732],
#         [ 1.23391474,  1.66275825,  0.9226124 , -1.26459638, -1.03803466,
#           0.57721407,  0.0851728 ],
#         [ 0.88014413, -0.01643332,  0.99393392,  0.22148362,  0.66548385,
#           0.46655683,  0.56526644],
#         [-0.64966599, -1.00074881, -0.45409884, -0.80864505, -0.78145147,
#          -0.60818995, -0.96187524],
#         [ 0.45505192,  0.62130454, -0.37732475, -1.11964016, -1.63809562,
#          -1.03441302, -0.64620098]]),
#  array([ 4.74109712, -0.30708097, -0.44751648,  3.72618536, -8.30549925,
#         -2.27847597,  0.62855892,  4.9221156 , -1.96002862, -3.96007412]),
#     Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
#  0   0.936409   0.256032   0.526228  -0.366193  -0.631129   0.257220
#  1  -0.205997   0.602647  -0.152347  -0.581254  -0.530710   0.345964
#  2   0.667947   0.642290   0.531849   0.038886  -0.145255   0.471068
#  3   1.095605   1.099945   0.745437  -1.729777  -2.331953   0.774363
#  4  -0.397468   0.094865  -0.975863  -1.415618  -1.440534  -1.878357
#  5  -0.200860  -0.722474  -0.515720  -0.282903  -0.087604  -0.036636
#  6   1.233915   1.662758   0.922612  -1.264596  -1.038035   0.577214
#  7   0.880144  -0.016433   0.993934   0.221484   0.665484   0.466557
#  8  -0.649666  -1.000749  -0.454099  -0.808645  -0.781451  -0.608190
#  9   0.455052   0.621305  -0.377325  -1.119640  -1.638096  -1.034413
#
#     Feature_7    Target
#  0  -0.252263  4.741097
#  1  -0.242501 -0.307081
#  2   0.880943 -0.447516
#  3  -1.063782  3.726185
#  4  -1.560661 -8.305499
#  5  -0.639457 -2.278476
#  6   0.085173  0.628559
#  7   0.565266  4.922116
#  8  -0.961875 -1.960029
#  9  -0.646201 -3.960074  ,
#  array([ 3.5, -2.1,  1.8,  4.2, -1.5,  2.7, -3. ]))

# %%
def ridge(X, y, alpha, lambda_param, n_iterations):
  n_samples, n_features = X.shape
  weights = np.zeros(n_features)
  bias = 0

  for i in range(n_iterations):
    y_predicted = X.dot(weights) + bias

    dw = (1/n_samples) * (X.T.dot(y_predicted - y) + lambda_param * weights)
    db = (1/n_samples) * np.sum(y_predicted - y)

    weights -= alpha * dw
    bias -= alpha * db
    if np.isnan(weights).any() or np.isnan(bias):
        print(f"Warning: NaN values encountered in weights or bias at iteration {i} for alpha={alpha}, lambda_param={lambda_param}. Stopping training for this parameter combination.")
        return weights, bias

  return weights, bias

# %%
def ridge_boosting(X, y, alpha, lambda_param, n_estimators, learning_rate):
    n_samples = X.shape[0]
    models = []
    residuals = y.copy()

    for i in range(n_estimators):
        ridge_output = ridge(X, residuals, alpha, lambda_param, n_iterations=1000)
        print(f"Iteration {i}: Output from ridge function: {ridge_output}")
        weights, bias = ridge_output

        if np.isnan(weights).any() or np.isnan(bias):
             print(f"Warning: NaN values received from ridge function at boosting iteration {i}. Stopping boosting for this parameter combination.")
             break

        predictions = X.dot(weights) + bias
        residuals -= learning_rate * predictions
        models.append((weights, bias))

    return models

# %%
def predict_ridge_boosting(models, X, learning_rate):
    n_samples = X.shape[0]
    y_pred = np.zeros(n_samples)

    for weights, bias in models:
        y_pred += learning_rate * (X.dot(weights) + bias)

    return y_pred

# %%
alpha_values = [0.0001, 0.001, 0.01, 0.1, 1, 10]
lambda_values = [1e-15, 1e-10, 1e-5, 1e-3, 0, 1, 10, 20]
boosting_learning_rate = 0.1
n_estimators = 100
X, y, df, true_coefficients = generate_correlated_data(n_samples=500)
X_train = X
y_train = y
X_test = X
y_test = y

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

results = []

for alpha in alpha_values:
    for lambda_param in lambda_values:
        print(f"Training with alpha={alpha}, lambda_param={lambda_param}")
        models = ridge_boosting(X_train_scaled, y_train, alpha, lambda_param, n_estimators, boosting_learning_rate)
        y_test_pred = predict_ridge_boosting(models, X_test_scaled, boosting_learning_rate)
        y_train_pred = predict_ridge_boosting(models, X_train_scaled, boosting_learning_rate)
        if not np.isnan(y_test_pred).any() and not np.isnan(y_train_pred).any():
            train_mse = mean_squared_error(y_train, y_train_pred)
            test_mse = mean_squared_error(y_test, y_test_pred)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2 = r2_score(y_test, y_test_pred)
            results.append({
                  'alpha': alpha,
                  'lambda_param': lambda_param,
                  'train_mse': train_mse,
                  'test_mse': test_mse,
                  'train_r2': train_r2,
                  'test_r2': test_r2,
              })
        else:
            print(f"Skipping evaluation for alpha={alpha}, lambda_param={lambda_param} due to NaN predictions.")


results_df = pd.DataFrame(results)
display(results_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#        0.11675464, 0.0171985 ]), np.float64(0.014313759540498246))
# Iteration 39: Output from ridge function: (array([0.1055422 , 0.04018807, 0.0946398 , 0.07716632, 0.01341698,
#        0.1138877 , 0.01507983]), np.float64(0.01417753963272148))
# Iteration 40: Output from ridge function: (array([0.10301163, 0.03777365, 0.09186993, 0.07576747, 0.01214768,
#        0.11111196, 0.01303585]), np.float64(0.014042616090390935))
# Iteration 41: Output from ridge function: (array([0.10056011, 0.0354368 , 0.08918856, 0.07441733, 0.01092501,
#        0.10842443, 0.01106407]), np.float64(0.013908976576371867))
# Iteration 42: Output from ridge function: (array([0.09818513, 0.03317502, 0.08659283, 0.07311422, 0.00974735,
#        0.10582223, 0.00916205]), np.float64(0.013776608870938343))
# Iteration 43: Output from ridge function: (array([0.09588424, 0.03098592, 0.08407998, 0.07185651, 0.00861313,
#        0.10330259, 0.00732745]), np.float64(0.013645500870656094))
# Iteration 44: Output from ridge function: (array([0.09365509, 0.02886718, 0.08164733, 0.07064262, 0.00752084,
#        0.10086281, 0.00555799]), np.float64(0.013515640587275604))
# Iteration 45: Output from ridge function: (array([0.09149538, 0.02681657, 0.0792923 , 0.06947104, 0.00646902,
#        0.09850028, 0.00385149]), np.float64(0.013387016146636227))
# Iteration 46: Output from ridge function: (array([0.0894029 , 0.0248319 , 0.07701238, 0.06834031, 0.00545627,
#        0.09621249, 0.00220582]), np.float64(0.013259615787580186))
# Iteration 47: Output from ridge function: (array([0.08737551, 0.02291108, 0.07480515, 0.067249  , 0.00448121,
#        0.093997  , 0.00061893]), np.float64(0.013133427860877235))
# Iteration 48: Output from ridge function: (array([ 0.08541114,  0.02105207,  0.07266826,  0.06619575,  0.00354254,
#         0.09185145, -0.00091116]), np.float64(0.013008440828159527))
# Iteration 49: Output from ridge function: (array([ 0.08350777,  0.01925291,  0.07059944,  0.06517923,  0.00263898,
#         0.08977357, -0.00238636]), np.float64(0.012884643260866432))
# Iteration 50: Output from ridge function: (array([ 0.08166348,  0.01751168,  0.06859651,  0.06419816,  0.0017693 ,
#         0.08776114, -0.00380853]), np.float64(0.012762023839199743))
# Iteration 51: Output from ridge function: (array([ 0.07987637,  0.01582654,  0.06665733,  0.06325131,  0.00093233,
#         0.08581204, -0.00517946]), np.float64(0.012640571351088372))
# Iteration 52: Output from ridge function: (array([ 0.07814464,  0.01419571,  0.06477986,  0.0623375 ,  0.0001269 ,
#         0.0839242 , -0.00650087]), np.float64(0.012520274691163399))
# Iteration 53: Output from ridge function: (array([ 0.07646652,  0.01261745,  0.0629621 ,  0.06145556, -0.00064807,
#         0.08209563, -0.00777445]), np.float64(0.012401122859742384))
# Iteration 54: Output from ridge function: (array([ 0.0748403 ,  0.01109011,  0.06120213,  0.06060438, -0.00139368,
#         0.08032439, -0.0090018 ]), np.float64(0.01228310496182371))
# Iteration 55: Output from ridge function: (array([ 0.07326434,  0.00961206,  0.05949809,  0.05978289, -0.00211093,
#         0.07860862, -0.0101845 ]), np.float64(0.012166210206090376))
# Iteration 56: Output from ridge function: (array([ 0.07173705,  0.00818172,  0.05784818,  0.05899005, -0.00280084,
#         0.07694651, -0.01132405]), np.float64(0.01205042790392317))
# Iteration 57: Output from ridge function: (array([ 0.07025687,  0.0067976 ,  0.05625065,  0.05822487, -0.00346437,
#         0.07533631, -0.01242191]), np.float64(0.011935747468423383))
# Iteration 58: Output from ridge function: (array([ 0.06882231,  0.00545821,  0.05470382,  0.05748636, -0.00410244,
#         0.07377633, -0.01347949]), np.float64(0.01182215841344481))
# Iteration 59: Output from ridge function: (array([ 0.06743192,  0.00416214,  0.05320607,  0.05677359, -0.00471595,
#         0.07226495, -0.01449817]), np.float64(0.011709650352634823))
# Iteration 60: Output from ridge function: (array([ 0.06608432,  0.00290801,  0.0517558 ,  0.05608566, -0.00530578,
#         0.07080057, -0.01547925]), np.float64(0.011598212998484667))
# Iteration 61: Output from ridge function: (array([ 0.06477812,  0.00169449,  0.05035149,  0.05542171, -0.00587276,
#         0.06938167, -0.01642402]), np.float64(0.011487836161388928))
# Iteration 62: Output from ridge function: (array([ 0.06351204,  0.0005203 ,  0.04899167,  0.05478087, -0.0064177 ,
#         0.06800676, -0.01733371]), np.float64(0.011378509748713623))
# Iteration 63: Output from ridge function: (array([ 0.06228479, -0.00061581,  0.0476749 ,  0.05416235, -0.00694137,
#         0.06667442, -0.0182095 ]), np.float64(0.011270223763873552))
# Iteration 64: Output from ridge function: (array([ 0.06109514, -0.00171506,  0.0463998 ,  0.05356535, -0.00744455,
#         0.06538326, -0.01905255]), np.float64(0.01116296830541799))
# Iteration 65: Output from ridge function: (array([ 0.05994192, -0.0027786 ,  0.04516503,  0.05298912, -0.00792794,
#         0.06413195, -0.01986398]), np.float64(0.011056733566125588))
# Iteration 66: Output from ridge function: (array([ 0.05882395, -0.00380757,  0.0439693 ,  0.05243292, -0.00839227,
#         0.06291918, -0.02064485]), np.float64(0.010951509832107346))
# Iteration 67: Output from ridge function: (array([ 0.05774014, -0.00480307,  0.04281134,  0.05189604, -0.0088382 ,
#         0.0617437 , -0.02139621]), np.float64(0.010847287481918665))
# Iteration 68: Output from ridge function: (array([ 0.05668939, -0.00576615,  0.04168996,  0.05137781, -0.0092664 ,
#         0.0606043 , -0.02211907]), np.float64(0.010744056985679361))
# Iteration 69: Output from ridge function: (array([ 0.05567067, -0.00669783,  0.04060397,  0.05087755, -0.00967749,
#         0.05949982, -0.02281439]), np.float64(0.010641808904202469))
# Iteration 70: Output from ridge function: (array([ 0.05468297, -0.00759912,  0.03955224,  0.05039464, -0.0100721 ,
#         0.0584291 , -0.02348311]), np.float64(0.010540533888130877))
# Iteration 71: Output from ridge function: (array([ 0.05372529, -0.00847097,  0.03853367,  0.04992845, -0.0104508 ,
#         0.05739106, -0.02412615]), np.float64(0.01044022267708272))
# Iteration 72: Output from ridge function: (array([ 0.05279671, -0.00931432,  0.03754719,  0.04947839, -0.01081417,
#         0.05638464, -0.02474437]), np.float64(0.010340866098804479))
# Iteration 73: Output from ridge function: (array([ 0.0518963 , -0.01013006,  0.03659177,  0.04904389, -0.01116277,
#         0.05540881, -0.02533863]), np.float64(0.0102424550683323))
# Iteration 74: Output from ridge function: (array([ 0.05102316, -0.01091906,  0.03566643,  0.0486244 , -0.01149711,
#         0.05446257, -0.02590974]), np.float64(0.010144980587161324))
# Iteration 75: Output from ridge function: (array([ 0.05017645, -0.01168218,  0.0347702 ,  0.04821937, -0.01181773,
#         0.05354496, -0.0264585 ]), np.float64(0.010048433742422834))
# Iteration 76: Output from ridge function: (array([ 0.04935533, -0.01242022,  0.03390213,  0.04782829, -0.0121251 ,
#         0.05265507, -0.02698567]), np.float64(0.009952805706069332))
# Iteration 77: Output from ridge function: (array([ 0.04855899, -0.01313398,  0.03306134,  0.04745067, -0.01241971,
#         0.05179197, -0.027492  ]), np.float64(0.009858087734067282))
# Iteration 78: Output from ridge function: (array([ 0.04778666, -0.01382422,  0.03224694,  0.04708602, -0.01270202,
#         0.05095482, -0.02797819]), np.float64(0.009764271165597553))
# Iteration 79: Output from ridge function: (array([ 0.04703758, -0.01449169,  0.0314581 ,  0.04673387, -0.01297248,
#         0.05014276, -0.02844493]), np.float64(0.009671347422263575))
# Iteration 80: Output from ridge function: (array([ 0.04631102, -0.0151371 ,  0.03069398,  0.04639379, -0.01323152,
#         0.04935498, -0.02889291]), np.float64(0.009579308007306903))
# Iteration 81: Output from ridge function: (array([ 0.04560626, -0.01576115,  0.02995382,  0.04606532, -0.01347955,
#         0.0485907 , -0.02932275]), np.float64(0.00948814450483024))
# Iteration 82: Output from ridge function: (array([ 0.04492264, -0.01636451,  0.02923682,  0.04574806, -0.01371698,
#         0.04784915, -0.02973508]), np.float64(0.009397848579027925))
# Iteration 83: Output from ridge function: (array([ 0.04425947, -0.01694782,  0.02854226,  0.0454416 , -0.01394418,
#         0.0471296 , -0.03013051]), np.float64(0.009308411973423818))
# Iteration 84: Output from ridge function: (array([ 0.04361613, -0.01751174,  0.02786942,  0.04514555, -0.01416154,
#         0.04643133, -0.03050962]), np.float64(0.009219826510116233))
# Iteration 85: Output from ridge function: (array([ 0.04299199, -0.01805685,  0.02721761,  0.04485954, -0.01436941,
#         0.04575366, -0.03087296]), np.float64(0.009132084089030237))
# Iteration 86: Output from ridge function: (array([ 0.04238644, -0.01858375,  0.02658614,  0.0445832 , -0.01456814,
#         0.04509592, -0.0312211 ]), np.float64(0.009045176687176937))
# Iteration 87: Output from ridge function: (array([ 0.04179891, -0.01909302,  0.02597438,  0.04431618, -0.01475807,
#         0.04445746, -0.03155454]), np.float64(0.008959096357919912))
# Iteration 88: Output from ridge function: (array([ 0.04122883, -0.01958522,  0.02538169,  0.04405815, -0.01493953,
#         0.04383766, -0.0318738 ]), np.float64(0.00887383523024857))
# Iteration 89: Output from ridge function: (array([ 0.04067566, -0.02006086,  0.02480746,  0.04380877, -0.01511282,
#         0.04323592, -0.03217936]), np.float64(0.008789385508058477))
# Iteration 90: Output from ridge function: (array([ 0.04013886, -0.02052048,  0.0242511 ,  0.04356773, -0.01527824,
#         0.04265166, -0.03247171]), np.float64(0.008705739469438437))
# Iteration 91: Output from ridge function: (array([ 0.03961793, -0.02096458,  0.02371205,  0.04333473, -0.01543609,
#         0.0420843 , -0.0327513 ]), np.float64(0.008622889465964475))
# Iteration 92: Output from ridge function: (array([ 0.03911236, -0.02139364,  0.02318975,  0.04310947, -0.01558665,
#         0.0415333 , -0.03301857]), np.float64(0.008540827922000439))
# Iteration 93: Output from ridge function: (array([ 0.03862168, -0.02180814,  0.02268367,  0.04289168, -0.01573019,
#         0.04099813, -0.03327395]), np.float64(0.008459547334005314))
# Iteration 94: Output from ridge function: (array([ 0.03814543, -0.02220853,  0.02219329,  0.04268107, -0.01586697,
#         0.04047829, -0.03351785]), np.float64(0.008379040269847147))
# Iteration 95: Output from ridge function: (array([ 0.03768315, -0.02259525,  0.02171811,  0.04247738, -0.01599724,
#         0.03997328, -0.03375068]), np.float64(0.008299299368123358))
# Iteration 96: Output from ridge function: (array([ 0.03723441, -0.02296874,  0.02125764,  0.04228036, -0.01612125,
#         0.03948261, -0.03397281]), np.float64(0.0082203173374878))
# Iteration 97: Output from ridge function: (array([ 0.03679879, -0.0233294 ,  0.02081142,  0.04208977, -0.01623924,
#         0.03900584, -0.03418463]), np.float64(0.008142086955983882))
# Iteration 98: Output from ridge function: (array([ 0.03637587, -0.02367764,  0.020379  ,  0.04190536, -0.01635142,
#         0.0385425 , -0.03438649]), np.float64(0.008064601070384321))
# Iteration 99: Output from ridge function: (array([ 0.03596527, -0.02401385,  0.01995993,  0.0417269 , -0.01645801,
#         0.03809216, -0.03457874]), np.float64(0.007987852595536993))
# Training with alpha=0.001, lambda_param=1e-15
# Iteration 0: Output from ridge function: (array([1.12015522, 0.46824885, 1.02276533, 0.8236625 , 0.1870747 ,
#        1.21497754, 0.22651539]), np.float64(0.13677331330587483))
# Iteration 1: Output from ridge function: (array([1.03299124, 0.38943366, 0.92951229, 0.77840006, 0.15024856,
#        1.11896988, 0.16618263]), np.float64(0.1281250741286208))
# Iteration 2: Output from ridge function: (array([0.95412345, 0.31870198, 0.84529396, 0.73731352, 0.11732546,
#        1.03184276, 0.11242795]), np.float64(0.12002366707131205))
# Iteration 3: Output from ridge function: (array([0.8827466 , 0.25526281, 0.76922901, 0.69998586, 0.08790922,
#        0.95273726, 0.06458909]), np.float64(0.11243451568881635))
# Iteration 4: Output from ridge function: (array([0.81813371, 0.19840211, 0.70052211, 0.66604198, 0.06164358,
#        0.88087842, 0.02206958]), np.float64(0.10532522982044634))
# Iteration 5: Output from ridge function: (array([ 0.7596285 ,  0.14747533,  0.63845557,  0.63514448,  0.03820821,
#         0.81556702, -0.01566773]), np.float64(0.09866546735019473))
# Iteration 6: Output from ridge function: (array([ 0.70663844,  0.10190059,  0.58238176,  0.60698984,  0.01731509,
#         0.75617214, -0.04910658]), np.float64(0.09242680470793074))
# Iteration 7: Output from ridge function: (array([ 0.65862861,  0.06115265,  0.53171623,  0.5813051 , -0.00129473,
#         0.70212449, -0.0786826 ]), np.float64(0.0865826155588683))
# Iteration 8: Output from ridge function: (array([ 0.61511609,  0.02475735,  0.48593162,  0.5578447 , -0.01785406,
#         0.65291034, -0.10478804]), np.float64(0.08110795716355133))
# Iteration 9: Output from ridge function: (array([ 0.57566487, -0.00771331,  0.444552  ,  0.53638781, -0.03257222,
#         0.60806613, -0.12777612]), np.float64(0.07597946392335199))
# Iteration 10: Output from ridge function: (array([ 0.53988132, -0.0366457 ,  0.4071479 ,  0.51673578, -0.04563734,
#         0.56717349, -0.14796486]), np.float64(0.07117524765713332))
# Iteration 11: Output from ridge function: (array([ 0.50741007, -0.06238857,  0.37333178,  0.49870998, -0.05721858,
#         0.52985489, -0.16564059]), np.float64(0.06667480418346687))
# Iteration 12: Output from ridge function: (array([ 0.47793026, -0.08525673,  0.34275389,  0.48214971, -0.06746797,
#         0.49576957, -0.1810611 ]), np.float64(0.06245892580969636))
# Iteration 13: Output from ridge function: (array([ 0.45115223, -0.10553435,  0.31509863,  0.46691047, -0.07652216,
#         0.46460998, -0.19445844]), np.float64(0.05850961935436005))
# Iteration 14: Output from ridge function: (array([ 0.42681444, -0.12347791,  0.29008121,  0.45286228, -0.08450398,
#         0.43609852, -0.20604152]), np.float64(0.054810029353093016))
# Iteration 15: Output from ridge function: (array([ 0.40468078, -0.13931895,  0.2674446 ,  0.43988824, -0.09152381,
#         0.40998459, -0.21599837]), np.float64(0.051344366120253074))
# Iteration 16: Output from ridge function: (array([ 0.38453807, -0.15326644,  0.24695687,  0.42788322, -0.09768085,
#         0.38604198, -0.22449822]), np.float64(0.04809783835924604))
# Iteration 17: Output from ridge function: (array([ 0.36619383, -0.16550897,  0.22840872,  0.41675267, -0.10306425,
#         0.36406645, -0.23169338]), np.float64(0.04505659003392828))
# Iteration 18: Output from ridge function: (array([ 0.34947429, -0.17621678,  0.21161128,  0.40641154, -0.10775411,
#         0.34387362, -0.23772091]), np.float64(0.04220764123166108))
# Iteration 19: Output from ridge function: (array([ 0.33422257, -0.18554351,  0.1963941 ,  0.39678336, -0.11182241,
#         0.32529699, -0.24270413]), np.float64(0.0395388327656206))
# Iteration 20: Output from ridge function: (array([ 0.320297  , -0.19362781,  0.18260335,  0.38779934, -0.11533382,
#         0.30818618, -0.246754  ]), np.float64(0.03703877427992887))
# Iteration 21: Output from ridge function: (array([ 0.30756969, -0.20059482,  0.17010024,  0.37939761, -0.11834643,
#         0.29240541, -0.24997034]), np.float64(0.03469679563612136))
# Iteration 22: Output from ridge function: (array([ 0.29592518, -0.20655746,  0.1587595 ,  0.37152253, -0.12091242,
#         0.27783204, -0.25244292]), np.float64(0.032502901373470755))
# Iteration 23: Output from ridge function: (array([ 0.28525921, -0.21161763,  0.14846809,  0.36412404, -0.12307869,
#         0.26435525, -0.2542525 ]), np.float64(0.030447728048804395))
# Iteration 24: Output from ridge function: (array([ 0.27547764, -0.21586726,  0.139124  ,  0.35715713, -0.12488733,
#         0.25187496, -0.25547169]), np.float64(0.028522504273745555))
# Iteration 25: Output from ridge function: (array([ 0.26649549, -0.21938933,  0.13063517,  0.3505813 , -0.12637617,
#         0.24030071, -0.25616576]), np.float64(0.026719013278817674))
# Iteration 26: Output from ridge function: (array([ 0.25823602, -0.22225867,  0.12291853,  0.34436013, -0.12757915,
#         0.22955077, -0.25639342]), np.float64(0.025029557844637472))
# Iteration 27: Output from ridge function: (array([ 0.25062996, -0.22454283,  0.1158991 ,  0.33846085, -0.12852678,
#         0.21955126, -0.25620741]), np.float64(0.023446927450525065))
# Iteration 28: Output from ridge function: (array([ 0.24361474, -0.2263027 ,  0.10950923,  0.33285398, -0.12924644,
#         0.21023539, -0.25565512]), np.float64(0.021964367500322005))
# Iteration 29: Output from ridge function: (array([ 0.23713389, -0.22759323,  0.10368788,  0.327513  , -0.1297627 ,
#         0.20154278, -0.25477913]), np.float64(0.020575550494075463))
# Iteration 30: Output from ridge function: (array([ 0.23113641, -0.22846399,  0.09837994,  0.32241404, -0.13009762,
#         0.19341882, -0.25361769]), np.float64(0.0192745490225495))
# Iteration 31: Output from ridge function: (array([ 0.22557627, -0.22895966,  0.09353569,  0.31753562, -0.13027103,
#         0.1858141 , -0.25220514]), np.float64(0.018055810469306013))
# Iteration 32: Output from ridge function: (array([ 0.22041188, -0.22912053,  0.08911028,  0.31285842, -0.13030067,
#         0.17868394, -0.2505723 ]), np.float64(0.016914133312384998))
# Iteration 33: Output from ridge function: (array([ 0.21560572, -0.22898296,  0.08506319,  0.30836504, -0.13020251,
#         0.17198788, -0.24874685]), np.float64(0.015844644924439502))
# Iteration 34: Output from ridge function: (array([ 0.2111239 , -0.22857968,  0.08135791,  0.30403981, -0.12999085,
#         0.16568931, -0.24675359]), np.float64(0.01484278077657924))
# Iteration 35: Output from ridge function: (array([ 0.20693581, -0.22794022,  0.07796145,  0.29986865, -0.12967853,
#         0.15975507, -0.24461479]), np.float64(0.013904264957163981))
# Iteration 36: Output from ridge function: (array([ 0.20301384, -0.22709119,  0.07484406,  0.29583884, -0.12927706,
#         0.15415513, -0.24235038]), np.float64(0.013025091922402816))
# Iteration 37: Output from ridge function: (array([ 0.19933302, -0.22605657,  0.0719789 ,  0.29193896, -0.12879676,
#         0.14886228, -0.23997824]), np.float64(0.012201509400871424))
# Iteration 38: Output from ridge function: (array([ 0.19587085, -0.22485795,  0.06934171,  0.2881587 , -0.12824689,
#         0.14385186, -0.23751437]), np.float64(0.011430002378984293))
# Iteration 39: Output from ridge function: (array([ 0.19260698, -0.22351478,  0.06691065,  0.28448877, -0.12763574,
#         0.1391015 , -0.2349731 ]), np.float64(0.010707278099073248))
# Iteration 40: Output from ridge function: (array([ 0.18952306, -0.22204457,  0.06466598,  0.28092081, -0.12697075,
#         0.13459091, -0.23236723]), np.float64(0.01003025200604389))
# Iteration 41: Output from ridge function: (array([ 0.1866025 , -0.22046309,  0.0625899 ,  0.27744728, -0.12625859,
#         0.13030167, -0.22970822]), np.float64(0.009396034582631713))
# Iteration 42: Output from ridge function: (array([ 0.18383033, -0.21878454,  0.06066632,  0.27406135, -0.12550521,
#         0.12621707, -0.2270063 ]), np.float64(0.008801919017070897))
# Iteration 43: Output from ridge function: (array([ 0.18119305, -0.21702166,  0.05888077,  0.27075691, -0.12471597,
#         0.12232192, -0.22427059]), np.float64(0.008245369650541932))
# Iteration 44: Output from ridge function: (array([ 0.17867843, -0.21518595,  0.05722014,  0.26752839, -0.12389565,
#         0.1186024 , -0.22150924]), np.float64(0.007724011155092724))
# Iteration 45: Output from ridge function: (array([ 0.17627547, -0.21328772,  0.05567264,  0.2643708 , -0.12304853,
#         0.11504597, -0.21872948]), np.float64(0.007235618395844204))
# Iteration 46: Output from ridge function: (array([ 0.17397422, -0.21133625,  0.0542276 ,  0.26127961, -0.12217843,
#         0.11164119, -0.21593778]), np.float64(0.0067781069342138425))
# Iteration 47: Output from ridge function: (array([ 0.17176568, -0.20933985,  0.05287542,  0.25825073, -0.1212888 ,
#         0.10837766, -0.21313985]), np.float64(0.006349524131624337))
# Iteration 48: Output from ridge function: (array([ 0.16964176, -0.20730601,  0.05160742,  0.25528046, -0.12038268,
#         0.10524588, -0.21034079]), np.float64(0.005948040815729008))
# Iteration 49: Output from ridge function: (array([ 0.16759511, -0.20524143,  0.05041577,  0.25236546, -0.11946282,
#         0.10223722, -0.2075451 ]), np.float64(0.005571943473585561))
# Iteration 50: Output from ridge function: (array([ 0.16561913, -0.20315213,  0.04929339,  0.24950269, -0.11853165,
#         0.09934377, -0.20475676]), np.float64(0.005219626938458988))
# Iteration 51: Output from ridge function: (array([ 0.16370784, -0.20104349,  0.04823393,  0.24668939, -0.11759137,
#         0.09655832, -0.20197929]), np.float64(0.0048895875390413445))
# Iteration 52: Output from ridge function: (array([ 0.16185585, -0.19892032,  0.04723163,  0.24392308, -0.11664391,
#         0.09387428, -0.19921579]), np.float64(0.004580416681849476))
# Iteration 53: Output from ridge function: (array([ 0.16005829, -0.19678695,  0.04628128,  0.24120149, -0.11569101,
#         0.09128561, -0.19646896]), np.float64(0.0042907948394106015))
# Iteration 54: Output from ridge function: (array([ 0.15831075, -0.19464723,  0.04537822,  0.23852255, -0.11473421,
#         0.08878677, -0.19374119]), np.float64(0.004019485918577753))
# Iteration 55: Output from ridge function: (array([ 0.15660927, -0.19250459,  0.0445182 ,  0.2358844 , -0.11377489,
#         0.08637271, -0.19103455]), np.float64(0.003765331984939211))
# Iteration 56: Output from ridge function: (array([ 0.15495025, -0.19036211,  0.04369743,  0.23328531, -0.11281427,
#         0.08403875, -0.18835085]), np.float64(0.0035272483208058886))
# Iteration 57: Output from ridge function: (array([ 0.15333045, -0.18822251,  0.04291245,  0.23072374, -0.11185344,
#         0.08178063, -0.18569165]), np.float64(0.0033042187956844413))
# Iteration 58: Output from ridge function: (array([ 0.15174694, -0.18608821,  0.04216015,  0.22819825, -0.11089336,
#         0.0795944 , -0.18305828]), np.float64(0.0030952915294775395))
# Iteration 59: Output from ridge function: (array([ 0.15019708, -0.18396137,  0.04143773,  0.22570754, -0.10993488,
#         0.07747643, -0.1804519 ]), np.float64(0.0028995748299019027))
# Iteration 60: Output from ridge function: (array([ 0.14867847, -0.18184389,  0.04074267,  0.22325043, -0.10897877,
#         0.07542337, -0.17787347]), np.float64(0.002716233386785319))
# Iteration 61: Output from ridge function: (array([ 0.14718897, -0.17973746,  0.04007267,  0.2208258 , -0.10802568,
#         0.07343214, -0.1753238 ]), np.float64(0.0025444847069999014))
# Iteration 62: Output from ridge function: (array([ 0.1457266 , -0.17764357,  0.03942568,  0.21843265, -0.1070762 ,
#         0.07149986, -0.17280358]), np.float64(0.0023835957748162637))
# Iteration 63: Output from ridge function: (array([ 0.14428961, -0.17556351,  0.03879984,  0.21607006, -0.10613087,
#         0.06962388, -0.17031334]), np.float64(0.002232879923424973))
# Iteration 64: Output from ridge function: (array([ 0.14287641, -0.17349843,  0.03819346,  0.21373717, -0.10519012,
#         0.06780176, -0.16785352]), np.float64(0.002091693904273099))
# Iteration 65: Output from ridge function: (array([ 0.14148555, -0.17144932,  0.03760502,  0.21143317, -0.10425436,
#         0.06603118, -0.16542447]), np.float64(0.001959435141708044))
# Iteration 66: Output from ridge function: (array([ 0.14011572, -0.16941705,  0.03703317,  0.20915734, -0.10332394,
#         0.06431004, -0.16302643]), np.float64(0.001835539161211393))
# Iteration 67: Output from ridge function: (array([ 0.13876575, -0.16740237,  0.03647666,  0.206909  , -0.10239915,
#         0.06263634, -0.16065958]), np.float64(0.001719477180246793))
# Iteration 68: Output from ridge function: (array([ 0.13743457, -0.16540592,  0.03593437,  0.2046875 , -0.10148027,
#         0.06100824, -0.158324  ]), np.float64(0.0016107538514396002))
# Iteration 69: Output from ridge function: (array([ 0.13612121, -0.16342824,  0.03540531,  0.20249226, -0.10056752,
#         0.05942399, -0.15601975]), np.float64(0.0015089051484562992))
# Iteration 70: Output from ridge function: (array([ 0.13482479, -0.1614698 ,  0.03488854,  0.20032272, -0.09966109,
#         0.05788197, -0.15374679]), np.float64(0.0014134963855607452))
# Iteration 71: Output from ridge function: (array([ 0.13354453, -0.15953098,  0.03438327,  0.19817836, -0.09876115,
#         0.05638067, -0.15150508]), np.float64(0.0013241203623947694))
# Iteration 72: Output from ridge function: (array([ 0.13227971, -0.1576121 ,  0.03388873,  0.19605869, -0.09786783,
#         0.05491864, -0.14929449]), np.float64(0.0012403956260651561))
# Iteration 73: Output from ridge function: (array([ 0.13102966, -0.1557134 ,  0.03340426,  0.19396325, -0.09698126,
#         0.05349455, -0.14711489]), np.float64(0.0011619648431196504))
# Iteration 74: Output from ridge function: (array([ 0.12979381, -0.15383509,  0.03292925,  0.1918916 , -0.09610153,
#         0.05210712, -0.14496609]), np.float64(0.001088493274463656))
# Iteration 75: Output from ridge function: (array([ 0.12857161, -0.15197732,  0.03246315,  0.18984334, -0.09522872,
#         0.05075515, -0.14284788]), np.float64(0.0010196673467087144))
# Iteration 76: Output from ridge function: (array([ 0.12736258, -0.15014019,  0.03200546,  0.18781808, -0.09436288,
#         0.0494375 , -0.14076003]), np.float64(0.0009551933138551556))
# Iteration 77: Output from ridge function: (array([ 0.12616626, -0.14832376,  0.03155573,  0.18581544, -0.09350407,
#         0.04815309, -0.13870229]), np.float64(0.0008947960035972776))
# Iteration 78: Output from ridge function: (array([ 0.12498227, -0.14652808,  0.03111356,  0.18383506, -0.09265233,
#         0.04690092, -0.13667438]), np.float64(0.0008382176429001632))
# Iteration 79: Output from ridge function: (array([ 0.12381023, -0.14475313,  0.03067857,  0.18187662, -0.09180767,
#         0.04568   , -0.134676  ]), np.float64(0.0007852167578358194))
# Iteration 80: Output from ridge function: (array([ 0.12264981, -0.14299889,  0.03025044,  0.17993978, -0.0909701 ,
#         0.04448941, -0.13270686]), np.float64(0.0007355671429832169))
# Iteration 81: Output from ridge function: (array([ 0.12150069, -0.1412653 ,  0.02982885,  0.17802424, -0.09013964,
#         0.04332827, -0.13076663]), np.float64(0.0006890568959935735))
# Iteration 82: Output from ridge function: (array([ 0.12036261, -0.13955229,  0.02941353,  0.17612969, -0.08931627,
#         0.04219573, -0.12885498]), np.float64(0.000645487513200591))
# Iteration 83: Output from ridge function: (array([ 0.1192353 , -0.13785977,  0.02900423,  0.17425585, -0.0885    ,
#         0.041091  , -0.12697159]), np.float64(0.0006046730424156006))
# Iteration 84: Output from ridge function: (array([ 0.11811853, -0.13618761,  0.02860072,  0.17240244, -0.08769079,
#         0.04001331, -0.12511611]), np.float64(0.0005664392892918978))
# Iteration 85: Output from ridge function: (array([ 0.11701208, -0.1345357 ,  0.0282028 ,  0.17056919, -0.08688863,
#         0.03896191, -0.12328818]), np.float64(0.0005306230738710223))
# Iteration 86: Output from ridge function: (array([ 0.11591575, -0.1329039 ,  0.02781028,  0.16875584, -0.08609349,
#         0.0379361 , -0.12148746]), np.float64(0.0004970715341379491))
# Iteration 87: Output from ridge function: (array([ 0.11482937, -0.13129204,  0.02742298,  0.16696213, -0.08530534,
#         0.0369352 , -0.1197136 ]), np.float64(0.00046564147361279176))
# Iteration 88: Output from ridge function: (array([ 0.11375275, -0.12969998,  0.02704075,  0.16518783, -0.08452414,
#         0.03595855, -0.11796623]), np.float64(0.000436198750194616))
# Iteration 89: Output from ridge function: (array([ 0.11268576, -0.12812753,  0.02666344,  0.16343268, -0.08374986,
#         0.03500552, -0.11624499]), np.float64(0.0004086177036488925))
# Iteration 90: Output from ridge function: (array([ 0.11162823, -0.12657452,  0.02629092,  0.16169647, -0.08298245,
#         0.03407551, -0.11454954]), np.float64(0.0003827806192952131))
# Iteration 91: Output from ridge function: (array([ 0.11058004, -0.12504077,  0.02592307,  0.15997895, -0.08222188,
#         0.03316793, -0.1128795 ]), np.float64(0.00035857722560627537))
# Iteration 92: Output from ridge function: (array([ 0.10954105, -0.12352609,  0.02555979,  0.15827992, -0.08146809,
#         0.03228222, -0.11123451]), np.float64(0.000335904223573895))
# Iteration 93: Output from ridge function: (array([ 0.10851116, -0.12203027,  0.02520096,  0.15659914, -0.08072104,
#         0.03141782, -0.10961423]), np.float64(0.0003146648458334467))
# Iteration 94: Output from ridge function: (array([ 0.10749025, -0.12055313,  0.0248465 ,  0.15493641, -0.07998069,
#         0.03057422, -0.1080183 ]), np.float64(0.0002947684436650238))
# Iteration 95: Output from ridge function: (array([ 0.10647821, -0.11909446,  0.02449631,  0.15329152, -0.07924697,
#         0.02975089, -0.10644635]), np.float64(0.0002761301001087786))
# Iteration 96: Output from ridge function: (array([ 0.10547495, -0.11765406,  0.02415032,  0.15166426, -0.07851984,
#         0.02894734, -0.10489804]), np.float64(0.00025867026754305587))
# Iteration 97: Output from ridge function: (array([ 0.10448038, -0.11623171,  0.02380844,  0.15005444, -0.07779925,
#         0.02816309, -0.10337303]), np.float64(0.00024231442817873437))
# Iteration 98: Output from ridge function: (array([ 0.10349441, -0.11482722,  0.02347062,  0.14846185, -0.07708515,
#         0.02739768, -0.10187096]), np.float64(0.00022699277602059262))
# Iteration 99: Output from ridge function: (array([ 0.10251695, -0.11344038,  0.02313678,  0.1468863 , -0.07637747,
#         0.02665065, -0.1003915 ]), np.float64(0.00021263991893842338))
# Training with alpha=0.001, lambda_param=1e-10
# Iteration 0: Output from ridge function: (array([1.12015522, 0.46824885, 1.02276533, 0.8236625 , 0.1870747 ,
#        1.21497754, 0.22651539]), np.float64(0.13677331330587483))
# Iteration 1: Output from ridge function: (array([1.03299124, 0.38943366, 0.92951229, 0.77840006, 0.15024856,
#        1.11896988, 0.16618263]), np.float64(0.1281250741286208))
# Iteration 2: Output from ridge function: (array([0.95412345, 0.31870198, 0.84529396, 0.73731352, 0.11732546,
#        1.03184276, 0.11242795]), np.float64(0.12002366707131208))
# Iteration 3: Output from ridge function: (array([0.8827466 , 0.25526281, 0.76922901, 0.69998586, 0.08790922,
#        0.95273726, 0.06458909]), np.float64(0.11243451568881638))
# Iteration 4: Output from ridge function: (array([0.81813371, 0.19840211, 0.70052211, 0.66604198, 0.06164358,
#        0.88087842, 0.02206958]), np.float64(0.10532522982044634))
# Iteration 5: Output from ridge function: (array([ 0.7596285 ,  0.14747533,  0.63845557,  0.63514448,  0.03820821,
#         0.81556702, -0.01566773]), np.float64(0.09866546735019474))
# Iteration 6: Output from ridge function: (array([ 0.70663844,  0.10190059,  0.58238176,  0.60698984,  0.01731509,
#         0.75617214, -0.04910658]), np.float64(0.09242680470793077))
# Iteration 7: Output from ridge function: (array([ 0.65862861,  0.06115265,  0.53171623,  0.5813051 , -0.00129473,
#         0.70212449, -0.0786826 ]), np.float64(0.08658261555886833))
# Iteration 8: Output from ridge function: (array([ 0.61511609,  0.02475735,  0.48593162,  0.5578447 , -0.01785406,
#         0.65291034, -0.10478804]), np.float64(0.08110795716355136))
# Iteration 9: Output from ridge function: (array([ 0.57566487, -0.00771331,  0.444552  ,  0.53638781, -0.03257222,
#         0.60806613, -0.12777612]), np.float64(0.07597946392335199))
# Iteration 10: Output from ridge function: (array([ 0.53988132, -0.0366457 ,  0.4071479 ,  0.51673578, -0.04563734,
#         0.56717349, -0.14796486]), np.float64(0.07117524765713332))
# Iteration 11: Output from ridge function: (array([ 0.50741007, -0.06238857,  0.37333178,  0.49870998, -0.05721858,
#         0.52985489, -0.16564059]), np.float64(0.06667480418346688))
# Iteration 12: Output from ridge function: (array([ 0.47793026, -0.08525673,  0.34275389,  0.48214971, -0.06746797,
#         0.49576957, -0.1810611 ]), np.float64(0.06245892580969636))
# Iteration 13: Output from ridge function: (array([ 0.45115223, -0.10553435,  0.31509863,  0.46691047, -0.07652216,
#         0.46460998, -0.19445844]), np.float64(0.05850961935436004))
# Iteration 14: Output from ridge function: (array([ 0.42681444, -0.12347791,  0.29008121,  0.45286228, -0.08450398,
#         0.43609852, -0.20604152]), np.float64(0.054810029353092996))
# Iteration 15: Output from ridge function: (array([ 0.40468078, -0.13931895,  0.2674446 ,  0.43988824, -0.09152381,
#         0.40998459, -0.21599837]), np.float64(0.05134436612025306))
# Iteration 16: Output from ridge function: (array([ 0.38453807, -0.15326644,  0.24695687,  0.42788322, -0.09768085,
#         0.38604198, -0.22449822]), np.float64(0.04809783835924602))
# Iteration 17: Output from ridge function: (array([ 0.36619383, -0.16550897,  0.22840872,  0.41675267, -0.10306425,
#         0.36406645, -0.23169338]), np.float64(0.045056590033928264))
# Iteration 18: Output from ridge function: (array([ 0.34947429, -0.17621678,  0.21161128,  0.40641154, -0.10775411,
#         0.34387362, -0.23772091]), np.float64(0.04220764123166107))
# Iteration 19: Output from ridge function: (array([ 0.33422257, -0.18554351,  0.1963941 ,  0.39678336, -0.11182241,
#         0.32529699, -0.24270413]), np.float64(0.039538832765620556))
# Iteration 20: Output from ridge function: (array([ 0.320297  , -0.19362781,  0.18260335,  0.38779934, -0.11533382,
#         0.30818618, -0.246754  ]), np.float64(0.03703877427992885))
# Iteration 21: Output from ridge function: (array([ 0.30756969, -0.20059482,  0.17010024,  0.37939761, -0.11834643,
#         0.29240541, -0.24997034]), np.float64(0.03469679563612134))
# Iteration 22: Output from ridge function: (array([ 0.29592518, -0.20655746,  0.1587595 ,  0.37152253, -0.12091242,
#         0.27783204, -0.25244292]), np.float64(0.03250290137347074))
# Iteration 23: Output from ridge function: (array([ 0.28525921, -0.21161763,  0.14846809,  0.36412404, -0.12307869,
#         0.26435525, -0.2542525 ]), np.float64(0.030447728048804377))
# Iteration 24: Output from ridge function: (array([ 0.27547764, -0.21586726,  0.139124  ,  0.35715713, -0.12488733,
#         0.25187496, -0.25547169]), np.float64(0.028522504273745537))
# Iteration 25: Output from ridge function: (array([ 0.26649549, -0.21938933,  0.13063517,  0.3505813 , -0.12637617,
#         0.24030071, -0.25616576]), np.float64(0.02671901327881766))
# Iteration 26: Output from ridge function: (array([ 0.25823602, -0.22225867,  0.12291853,  0.34436013, -0.12757915,
#         0.22955077, -0.25639342]), np.float64(0.025029557844637465))
# Iteration 27: Output from ridge function: (array([ 0.25062996, -0.22454283,  0.1158991 ,  0.33846085, -0.12852678,
#         0.21955126, -0.25620741]), np.float64(0.023446927450525044))
# Iteration 28: Output from ridge function: (array([ 0.24361474, -0.2263027 ,  0.10950923,  0.33285398, -0.12924644,
#         0.21023539, -0.25565512]), np.float64(0.021964367500321994))
# Iteration 29: Output from ridge function: (array([ 0.23713389, -0.22759323,  0.10368788,  0.327513  , -0.1297627 ,
#         0.20154278, -0.25477913]), np.float64(0.020575550494075473))
# Iteration 30: Output from ridge function: (array([ 0.23113641, -0.22846399,  0.09837994,  0.32241404, -0.13009762,
#         0.19341882, -0.25361769]), np.float64(0.019274549022549495))
# Iteration 31: Output from ridge function: (array([ 0.22557627, -0.22895966,  0.09353569,  0.31753562, -0.13027103,
#         0.1858141 , -0.25220514]), np.float64(0.01805581046930603))
# Iteration 32: Output from ridge function: (array([ 0.22041188, -0.22912053,  0.08911028,  0.31285842, -0.13030067,
#         0.17868394, -0.2505723 ]), np.float64(0.016914133312384987))
# Iteration 33: Output from ridge function: (array([ 0.21560572, -0.22898296,  0.08506319,  0.30836504, -0.13020251,
#         0.17198788, -0.24874685]), np.float64(0.015844644924439502))
# Iteration 34: Output from ridge function: (array([ 0.2111239 , -0.22857968,  0.08135791,  0.30403981, -0.12999085,
#         0.16568931, -0.24675359]), np.float64(0.014842780776579249))
# Iteration 35: Output from ridge function: (array([ 0.20693581, -0.22794022,  0.07796145,  0.29986865, -0.12967853,
#         0.15975507, -0.24461479]), np.float64(0.01390426495716398))
# Iteration 36: Output from ridge function: (array([ 0.20301384, -0.22709119,  0.07484406,  0.29583884, -0.12927706,
#         0.15415513, -0.24235038]), np.float64(0.013025091922402806))
# Iteration 37: Output from ridge function: (array([ 0.19933302, -0.22605657,  0.0719789 ,  0.29193896, -0.12879676,
#         0.14886228, -0.23997824]), np.float64(0.012201509400871424))
# Iteration 38: Output from ridge function: (array([ 0.19587085, -0.22485795,  0.06934171,  0.2881587 , -0.12824689,
#         0.14385186, -0.23751437]), np.float64(0.011430002378984306))
# Iteration 39: Output from ridge function: (array([ 0.19260698, -0.22351478,  0.06691065,  0.28448877, -0.12763574,
#         0.1391015 , -0.2349731 ]), np.float64(0.010707278099073248))
# Iteration 40: Output from ridge function: (array([ 0.18952306, -0.22204457,  0.06466598,  0.28092081, -0.12697075,
#         0.13459091, -0.23236723]), np.float64(0.010030252006043893))
# Iteration 41: Output from ridge function: (array([ 0.1866025 , -0.22046309,  0.0625899 ,  0.27744728, -0.12625859,
#         0.13030167, -0.22970822]), np.float64(0.009396034582631715))
# Iteration 42: Output from ridge function: (array([ 0.18383033, -0.21878454,  0.06066632,  0.27406135, -0.12550521,
#         0.12621707, -0.2270063 ]), np.float64(0.008801919017070895))
# Iteration 43: Output from ridge function: (array([ 0.18119305, -0.21702166,  0.05888077,  0.27075691, -0.12471597,
#         0.12232192, -0.22427059]), np.float64(0.00824536965054194))
# Iteration 44: Output from ridge function: (array([ 0.17867843, -0.21518595,  0.05722014,  0.26752839, -0.12389565,
#         0.1186024 , -0.22150924]), np.float64(0.007724011155092726))
# Iteration 45: Output from ridge function: (array([ 0.17627547, -0.21328772,  0.05567264,  0.2643708 , -0.12304853,
#         0.11504597, -0.21872948]), np.float64(0.007235618395844196))
# Iteration 46: Output from ridge function: (array([ 0.17397422, -0.21133625,  0.0542276 ,  0.26127961, -0.12217843,
#         0.11164119, -0.21593778]), np.float64(0.006778106934213837))
# Iteration 47: Output from ridge function: (array([ 0.17176568, -0.20933985,  0.05287542,  0.25825073, -0.1212888 ,
#         0.10837766, -0.21313985]), np.float64(0.006349524131624337))
# Iteration 48: Output from ridge function: (array([ 0.16964176, -0.20730601,  0.05160742,  0.25528046, -0.12038268,
#         0.10524588, -0.21034079]), np.float64(0.005948040815729008))
# Iteration 49: Output from ridge function: (array([ 0.16759511, -0.20524143,  0.05041577,  0.25236546, -0.11946282,
#         0.10223722, -0.2075451 ]), np.float64(0.005571943473585561))
# Iteration 50: Output from ridge function: (array([ 0.16561913, -0.20315213,  0.04929339,  0.24950269, -0.11853165,
#         0.09934377, -0.20475676]), np.float64(0.005219626938458994))
# Iteration 51: Output from ridge function: (array([ 0.16370784, -0.20104349,  0.04823393,  0.24668939, -0.11759137,
#         0.09655832, -0.20197929]), np.float64(0.004889587539041356))
# Iteration 52: Output from ridge function: (array([ 0.16185585, -0.19892032,  0.04723163,  0.24392308, -0.11664391,
#         0.09387428, -0.19921579]), np.float64(0.00458041668184949))
# Iteration 53: Output from ridge function: (array([ 0.16005829, -0.19678695,  0.04628128,  0.24120149, -0.11569101,
#         0.09128561, -0.19646896]), np.float64(0.004290794839410611))
# Iteration 54: Output from ridge function: (array([ 0.15831075, -0.19464723,  0.04537822,  0.23852255, -0.11473421,
#         0.08878677, -0.19374119]), np.float64(0.00401948591857777))
# Iteration 55: Output from ridge function: (array([ 0.15660927, -0.19250459,  0.0445182 ,  0.2358844 , -0.11377489,
#         0.08637271, -0.19103455]), np.float64(0.0037653319849392237))
# Iteration 56: Output from ridge function: (array([ 0.15495025, -0.19036211,  0.04369743,  0.23328531, -0.11281427,
#         0.08403875, -0.18835085]), np.float64(0.0035272483208058972))
# Iteration 57: Output from ridge function: (array([ 0.15333045, -0.18822251,  0.04291245,  0.23072374, -0.11185344,
#         0.08178063, -0.18569165]), np.float64(0.0033042187956844465))
# Iteration 58: Output from ridge function: (array([ 0.15174694, -0.18608821,  0.04216015,  0.22819825, -0.11089336,
#         0.0795944 , -0.18305828]), np.float64(0.0030952915294775434))
# Iteration 59: Output from ridge function: (array([ 0.15019708, -0.18396137,  0.04143773,  0.22570754, -0.10993488,
#         0.07747643, -0.1804519 ]), np.float64(0.0028995748299018988))
# Iteration 60: Output from ridge function: (array([ 0.14867847, -0.18184389,  0.04074267,  0.22325043, -0.10897877,
#         0.07542337, -0.17787347]), np.float64(0.0027162333867853153))
# Iteration 61: Output from ridge function: (array([ 0.14718897, -0.17973746,  0.04007267,  0.2208258 , -0.10802568,
#         0.07343214, -0.1753238 ]), np.float64(0.0025444847069998893))
# Iteration 62: Output from ridge function: (array([ 0.1457266 , -0.17764357,  0.03942568,  0.21843265, -0.1070762 ,
#         0.07149986, -0.17280358]), np.float64(0.0023835957748162555))
# Iteration 63: Output from ridge function: (array([ 0.14428961, -0.17556351,  0.03879984,  0.21607006, -0.10613087,
#         0.06962388, -0.17031334]), np.float64(0.002232879923424958))
# Iteration 64: Output from ridge function: (array([ 0.14287641, -0.17349843,  0.03819346,  0.21373717, -0.10519012,
#         0.06780176, -0.16785352]), np.float64(0.0020916939042730912))
# Iteration 65: Output from ridge function: (array([ 0.14148555, -0.17144932,  0.03760502,  0.21143317, -0.10425436,
#         0.06603118, -0.16542447]), np.float64(0.0019594351417080366))
# Iteration 66: Output from ridge function: (array([ 0.14011572, -0.16941705,  0.03703317,  0.20915734, -0.10332394,
#         0.06431004, -0.16302643]), np.float64(0.001835539161211378))
# Iteration 67: Output from ridge function: (array([ 0.13876575, -0.16740237,  0.03647666,  0.206909  , -0.10239915,
#         0.06263634, -0.16065958]), np.float64(0.0017194771802467711))
# Iteration 68: Output from ridge function: (array([ 0.13743457, -0.16540592,  0.03593437,  0.2046875 , -0.10148027,
#         0.06100824, -0.158324  ]), np.float64(0.0016107538514395698))
# Iteration 69: Output from ridge function: (array([ 0.13612121, -0.16342824,  0.03540531,  0.20249226, -0.10056752,
#         0.05942399, -0.15601975]), np.float64(0.0015089051484562682))
# Iteration 70: Output from ridge function: (array([ 0.13482479, -0.1614698 ,  0.03488854,  0.20032272, -0.09966109,
#         0.05788197, -0.15374679]), np.float64(0.0014134963855607203))
# Iteration 71: Output from ridge function: (array([ 0.13354453, -0.15953098,  0.03438327,  0.19817836, -0.09876115,
#         0.05638067, -0.15150508]), np.float64(0.0013241203623947455))
# Iteration 72: Output from ridge function: (array([ 0.13227971, -0.1576121 ,  0.03388873,  0.19605869, -0.09786783,
#         0.05491864, -0.14929449]), np.float64(0.001240395626065132))
# Iteration 73: Output from ridge function: (array([ 0.13102966, -0.1557134 ,  0.03340426,  0.19396325, -0.09698126,
#         0.05349455, -0.14711489]), np.float64(0.0011619648431196279))
# Iteration 74: Output from ridge function: (array([ 0.12979381, -0.15383509,  0.03292925,  0.1918916 , -0.09610153,
#         0.05210712, -0.14496609]), np.float64(0.0010884932744636459))
# Iteration 75: Output from ridge function: (array([ 0.12857161, -0.15197732,  0.03246315,  0.18984334, -0.09522872,
#         0.05075515, -0.14284788]), np.float64(0.0010196673467087081))
# Iteration 76: Output from ridge function: (array([ 0.12736258, -0.15014019,  0.03200546,  0.18781808, -0.09436288,
#         0.0494375 , -0.14076003]), np.float64(0.0009551933138551501))
# Iteration 77: Output from ridge function: (array([ 0.12616626, -0.14832376,  0.03155573,  0.18581544, -0.09350407,
#         0.04815309, -0.13870229]), np.float64(0.0008947960035972711))
# Iteration 78: Output from ridge function: (array([ 0.12498227, -0.14652808,  0.03111356,  0.18383506, -0.09265233,
#         0.04690092, -0.13667438]), np.float64(0.0008382176429001524))
# Iteration 79: Output from ridge function: (array([ 0.12381023, -0.14475313,  0.03067857,  0.18187662, -0.09180767,
#         0.04568   , -0.134676  ]), np.float64(0.0007852167578358045))
# Iteration 80: Output from ridge function: (array([ 0.12264981, -0.14299889,  0.03025044,  0.17993978, -0.0909701 ,
#         0.04448941, -0.13270686]), np.float64(0.0007355671429832008))
# Iteration 81: Output from ridge function: (array([ 0.12150069, -0.1412653 ,  0.02982885,  0.17802424, -0.09013964,
#         0.04332827, -0.13076663]), np.float64(0.0006890568959935611))
# Iteration 82: Output from ridge function: (array([ 0.12036261, -0.13955229,  0.02941353,  0.17612969, -0.08931627,
#         0.04219573, -0.12885498]), np.float64(0.0006454875132005827))
# Iteration 83: Output from ridge function: (array([ 0.1192353 , -0.13785977,  0.02900423,  0.17425585, -0.0885    ,
#         0.041091  , -0.12697159]), np.float64(0.000604673042415588))
# Iteration 84: Output from ridge function: (array([ 0.11811853, -0.13618761,  0.02860072,  0.17240244, -0.08769079,
#         0.04001331, -0.12511611]), np.float64(0.0005664392892918834))
# Iteration 85: Output from ridge function: (array([ 0.11701208, -0.1345357 ,  0.0282028 ,  0.17056919, -0.08688863,
#         0.03896191, -0.12328818]), np.float64(0.0005306230738710163))
# Iteration 86: Output from ridge function: (array([ 0.11591575, -0.1329039 ,  0.02781028,  0.16875584, -0.08609349,
#         0.0379361 , -0.12148746]), np.float64(0.000497071534137947))
# Iteration 87: Output from ridge function: (array([ 0.11482937, -0.13129204,  0.02742298,  0.16696213, -0.08530534,
#         0.0369352 , -0.1197136 ]), np.float64(0.0004656414736127889))
# Iteration 88: Output from ridge function: (array([ 0.11375275, -0.12969998,  0.02704075,  0.16518783, -0.08452414,
#         0.03595855, -0.11796623]), np.float64(0.0004361987501946195))
# Iteration 89: Output from ridge function: (array([ 0.11268576, -0.12812753,  0.02666344,  0.16343268, -0.08374986,
#         0.03500552, -0.11624499]), np.float64(0.00040861770364889225))
# Iteration 90: Output from ridge function: (array([ 0.11162823, -0.12657452,  0.02629092,  0.16169647, -0.08298245,
#         0.03407551, -0.11454954]), np.float64(0.000382780619295216))
# Iteration 91: Output from ridge function: (array([ 0.11058004, -0.12504077,  0.02592307,  0.15997895, -0.08222188,
#         0.03316793, -0.1128795 ]), np.float64(0.00035857722560628035))
# Iteration 92: Output from ridge function: (array([ 0.10954105, -0.12352609,  0.02555979,  0.15827992, -0.08146809,
#         0.03228222, -0.11123451]), np.float64(0.000335904223573906))
# Iteration 93: Output from ridge function: (array([ 0.10851116, -0.12203027,  0.02520096,  0.15659914, -0.08072104,
#         0.03141782, -0.10961423]), np.float64(0.000314664845833457))
# Iteration 94: Output from ridge function: (array([ 0.10749025, -0.12055313,  0.0248465 ,  0.15493641, -0.07998069,
#         0.03057422, -0.1080183 ]), np.float64(0.00029476844366503255))
# Iteration 95: Output from ridge function: (array([ 0.10647821, -0.11909446,  0.02449631,  0.15329152, -0.07924697,
#         0.02975089, -0.10644635]), np.float64(0.0002761301001087751))
# Iteration 96: Output from ridge function: (array([ 0.10547495, -0.11765406,  0.02415032,  0.15166426, -0.07851984,
#         0.02894734, -0.10489804]), np.float64(0.0002586702675430496))
# Iteration 97: Output from ridge function: (array([ 0.10448038, -0.11623171,  0.02380844,  0.15005444, -0.07779925,
#         0.02816309, -0.10337303]), np.float64(0.0002423144281787256))
# Iteration 98: Output from ridge function: (array([ 0.10349441, -0.11482722,  0.02347062,  0.14846185, -0.07708515,
#         0.02739768, -0.10187096]), np.float64(0.0002269927760205821))
# ...
#         0.00036923, -0.00191174]), np.float64(2.511486541621864e-05))
# Iteration 87: Output from ridge function: (array([ 0.00301441, -0.00252083,  0.00021786,  0.0038526 , -0.00227163,
#         0.00033184, -0.00176307]), np.float64(2.260337887458734e-05))
# Iteration 88: Output from ridge function: (array([ 0.00279391, -0.00233422,  0.00019299,  0.0035684 , -0.00210951,
#         0.00029812, -0.00162595]), np.float64(2.0343040987129494e-05))
# Iteration 89: Output from ridge function: (array([ 0.0025896 , -0.00216138,  0.00017067,  0.0033052 , -0.00195892,
#         0.00026772, -0.00149947]), np.float64(1.8308736888414506e-05))
# Iteration 90: Output from ridge function: (array([ 0.00240028, -0.00200132,  0.00015064,  0.00306145, -0.00181903,
#         0.00024033, -0.00138282]), np.float64(1.6477863199572406e-05))
# Iteration 91: Output from ridge function: (array([ 0.00222486, -0.00185308,  0.00013269,  0.00283569, -0.00168909,
#         0.00021564, -0.00127523]), np.float64(1.4830076879603375e-05))
# Iteration 92: Output from ridge function: (array([ 0.0020623 , -0.0017158 ,  0.00011661,  0.00262662, -0.00156839,
#         0.0001934 , -0.00117601]), np.float64(1.3347069191635798e-05))
# Iteration 93: Output from ridge function: (array([ 0.00191167, -0.00158867,  0.00010221,  0.00243298, -0.00145629,
#         0.00017337, -0.00108449]), np.float64(1.2012362272470519e-05))
# Iteration 94: Output from ridge function: (array([ 1.77206895e-03, -1.47093687e-03,  8.93482876e-05,  2.25363270e-03,
#        -1.35216282e-03,  1.55336009e-04, -1.00008760e-03]), np.float64(1.0811126045216189e-05))
# Iteration 95: Output from ridge function: (array([ 1.64269911e-03, -1.36191656e-03,  7.78556098e-05,  2.08752869e-03,
#        -1.25545705e-03,  1.39104864e-04, -9.22246602e-04]), np.float64(9.730013440695715e-06))
# Iteration 96: Output from ridge function: (array([ 1.52280437e-03, -1.26096268e-03,  6.76008927e-05,  1.93368464e-03,
#        -1.16564232e-03,  1.24500311e-04, -8.50458070e-04]), np.float64(8.75701209661842e-06))
# Iteration 97: Output from ridge function: (array([ 1.41168782e-03, -1.16748007e-03,  5.84611409e-05,  1.79119401e-03,
#        -1.08222989e-03,  1.11363647e-04, -7.84252187e-04]), np.float64(7.881310886964614e-06))
# Iteration 98: Output from ridge function: (array([ 1.30870409e-03, -1.08091730e-03,  5.03250596e-05,  1.65921747e-03,
#        -1.00476545e-03,  9.95513784e-05, -7.23195511e-04]), np.float64(7.093179798256703e-06))
# Iteration 99: Output from ridge function: (array([ 1.21325552e-03, -1.00076346e-03,  4.30919692e-05,  1.53697786e-03,
#        -9.32826759e-04,  8.89337812e-05, -6.66888176e-04]), np.float64(6.38386181842847e-06))
# Training with alpha=1, lambda_param=1e-15
# Warning: NaN values encountered in weights or bias at iteration 645 for alpha=1, lambda_param=1e-15. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=1e-10
# Warning: NaN values encountered in weights or bias at iteration 645 for alpha=1, lambda_param=1e-10. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=1e-05
# Warning: NaN values encountered in weights or bias at iteration 645 for alpha=1, lambda_param=1e-05. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=0.001
# Warning: NaN values encountered in weights or bias at iteration 645 for alpha=1, lambda_param=0.001. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=0
# Warning: NaN values encountered in weights or bias at iteration 645 for alpha=1, lambda_param=0. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=1
# Warning: NaN values encountered in weights or bias at iteration 644 for alpha=1, lambda_param=1. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=10
# Warning: NaN values encountered in weights or bias at iteration 641 for alpha=1, lambda_param=10. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=1, lambda_param=20
# Warning: NaN values encountered in weights or bias at iteration 637 for alpha=1, lambda_param=20. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=1e-15
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=1e-15. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=1e-10
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=1e-10. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=1e-05
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=1e-05. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=0.001
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=0.001. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=0
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=0. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=1
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /tmp/ipython-input-1049401367.py:9: RuntimeWarning: invalid value encountered in multiply
#   dw = (1/n_samples) * (X.T.dot(y_predicted - y) + lambda_param * weights)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /tmp/ipython-input-1049401367.py:9: RuntimeWarning: invalid value encountered in multiply
#   dw = (1/n_samples) * (X.T.dot(y_predicted - y) + lambda_param * weights)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=1. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=10
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=10. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# Training with alpha=10, lambda_param=20
# Warning: NaN values encountered in weights or bias at iteration 193 for alpha=10, lambda_param=20. Stopping training for this parameter combination.
# Iteration 0: Output from ridge function: (array([nan, nan, nan, nan, nan, nan, nan]), np.float64(nan))
# Warning: NaN values received from ridge function at boosting iteration 0. Stopping boosting for this parameter combination.
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#       alpha  lambda_param  train_mse   test_mse  train_r2   test_r2
# 0    0.0001  1.000000e-15   8.882533   8.882533  0.668599  0.668599
# 1    0.0001  1.000000e-10   8.882533   8.882533  0.668599  0.668599
# 2    0.0001  1.000000e-05   8.882533   8.882533  0.668599  0.668599
# 3    0.0001  1.000000e-03   8.882533   8.882533  0.668599  0.668599
# 4    0.0001  0.000000e+00   8.882533   8.882533  0.668599  0.668599
# 5    0.0001  1.000000e+00   8.882674   8.882674  0.668594  0.668594
# 6    0.0001  1.000000e+01   8.883937   8.883937  0.668547  0.668547
# 7    0.0001  2.000000e+01   8.885339   8.885339  0.668495  0.668495
# 8    0.0010  1.000000e-15   4.701098   4.701098  0.824606  0.824606
# 9    0.0010  1.000000e-10   4.701098   4.701098  0.824606  0.824606
# 10   0.0010  1.000000e-05   4.701098   4.701098  0.824606  0.824606
# 11   0.0010  1.000000e-03   4.701100   4.701100  0.824605  0.824605
# 12   0.0010  0.000000e+00   4.701098   4.701098  0.824606  0.824606
# 13   0.0010  1.000000e+00   4.702376   4.702376  0.824558  0.824558
# 14   0.0010  1.000000e+01   4.713924   4.713924  0.824127  0.824127
# 15   0.0010  2.000000e+01   4.726868   4.726868  0.823644  0.823644
# 16   0.0100  1.000000e-15   4.120377   4.120377  0.846272  0.846272
# 17   0.0100  1.000000e-10   4.120377   4.120377  0.846272  0.846272
# 18   0.0100  1.000000e-05   4.120377   4.120377  0.846272  0.846272
# 19   0.0100  1.000000e-03   4.120377   4.120377  0.846272  0.846272
# 20   0.0100  0.000000e+00   4.120377   4.120377  0.846272  0.846272
# 21   0.0100  1.000000e+00   4.120377   4.120377  0.846272  0.846272
# 22   0.0100  1.000000e+01   4.120386   4.120386  0.846271  0.846271
# 23   0.0100  2.000000e+01   4.120408   4.120408  0.846271  0.846271
# 24   0.1000  1.000000e-15   4.120372   4.120372  0.846272  0.846272
# 25   0.1000  1.000000e-10   4.120372   4.120372  0.846272  0.846272
# 26   0.1000  1.000000e-05   4.120372   4.120372  0.846272  0.846272
# 27   0.1000  1.000000e-03   4.120372   4.120372  0.846272  0.846272
# 28   0.1000  0.000000e+00   4.120372   4.120372  0.846272  0.846272
# 29   0.1000  1.000000e+00   4.120372   4.120372  0.846272  0.846272
# 30   0.1000  1.000000e+01   4.120373   4.120373  0.846272  0.846272
# 31   0.1000  2.000000e+01   4.120374   4.120374  0.846272  0.846272
# 32   1.0000  1.000000e-15  26.849790  26.849790 -0.001746 -0.001746
# 33   1.0000  1.000000e-10  26.849790  26.849790 -0.001746 -0.001746
# 34   1.0000  1.000000e-05  26.849790  26.849790 -0.001746 -0.001746
# 35   1.0000  1.000000e-03  26.849790  26.849790 -0.001746 -0.001746
# 36   1.0000  0.000000e+00  26.849790  26.849790 -0.001746 -0.001746
# 37   1.0000  1.000000e+00  26.849790  26.849790 -0.001746 -0.001746
# 38   1.0000  1.000000e+01  26.849790  26.849790 -0.001746 -0.001746
# 39   1.0000  2.000000e+01  26.849790  26.849790 -0.001746 -0.001746
# 40  10.0000  1.000000e-15  26.849790  26.849790 -0.001746 -0.001746
# 41  10.0000  1.000000e-10  26.849790  26.849790 -0.001746 -0.001746
# 42  10.0000  1.000000e-05  26.849790  26.849790 -0.001746 -0.001746
# 43  10.0000  1.000000e-03  26.849790  26.849790 -0.001746 -0.001746
# 44  10.0000  0.000000e+00  26.849790  26.849790 -0.001746 -0.001746
# 45  10.0000  1.000000e+00  26.849790  26.849790 -0.001746 -0.001746
# 46  10.0000  1.000000e+01  26.849790  26.849790 -0.001746 -0.001746
# 47  10.0000  2.000000e+01  26.849790  26.849790 -0.001746 -0.001746

# %%
best_mse_idx = results_df['test_mse'].idxmin()
best_mse_params = results_df.loc[best_mse_idx]
best_r2_idx = results_df['test_r2'].idxmax()
best_r2_params = results_df.loc[best_r2_idx]

print("Best parameters based on minimum test MSE:")
display(best_mse_params)

print("\nBest parameters based on maximum test R2 score:")
display(best_r2_params)
# Out:
# Best parameters based on minimum test MSE:
# alpha           1.000000e-01
# lambda_param    1.000000e-15
# train_mse       4.120372e+00
# test_mse        4.120372e+00
# train_r2        8.462720e-01
# test_r2         8.462720e-01
# Name: 24, dtype: float64
# Best parameters based on maximum test R2 score:
# alpha           1.000000e-01
# lambda_param    1.000000e-15
# train_mse       4.120372e+00
# test_mse        4.120372e+00
# train_r2        8.462720e-01
# test_r2         8.462720e-01
# Name: 24, dtype: float64

# %%
best_r2_idx = results_df['test_r2'].idxmax()
best_r2 = results[best_r2_idx]

# %%
best_r2_idx
# Out:
# 24

# %%
best_r2
# Out:
# {'alpha': 0.1,
#  'lambda_param': 1e-15,
#  'train_mse': 4.120372414216306,
#  'test_mse': 4.120372414216306,
#  'train_r2': 0.8462719697053458,
#  'test_r2': 0.8462719697053458}

# %%
#question 3

# %%
import pandas as pd
import numpy as np
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

X_boston = data
y_boston = target
print("Features shape:", X_boston.shape)
print("Target shape:", y_boston.shape)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2456288217.py:4: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
# Features shape: (506, 13)
# Target shape: (506,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_boston, y_boston, test_size=0.2, random_state=42)
print("Training features shape:", X_train.shape)
print("Testing features shape:", X_test.shape)
print("Training target shape:", y_train.shape)
print("Testing target shape:", y_test.shape)
# Out:
# Training features shape: (404, 13)
# Testing features shape: (102, 13)
# Training target shape: (404,)
# Testing target shape: (102,)

# %%
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn.model_selection import RepeatedKFold
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=42)
ridge_alphas = np.logspace(-6, 6, 13)
lasso_alphas = np.logspace(-6, 6, 13)

ridge_cv_model = RidgeCV(alphas=ridge_alphas, cv=cv)
ridge_cv_model.fit(X_train, y_train)

lasso_cv_model = LassoCV(alphas=lasso_alphas, cv=cv)
lasso_cv_model.fit(X_train, y_train)

print("Best alpha for RidgeCV:", ridge_cv_model.alpha_)
print("Best alpha for LassoCV:", lasso_cv_model.alpha_)
# Out:
# Best alpha for RidgeCV: 0.1
# Best alpha for LassoCV: 1e-06

# %%
#question 4

# %% [markdown]
# # Task
# Implement Multiclass Logistic Regression (step-by step) on Iris dataset using one vs. rest strategy.

# %% [markdown]
# ## Load the dataset
#
# ### Subtask:
# Load the Iris dataset using `load_iris` from `sklearn.datasets`.

# %% [markdown]
# **Reasoning**:
# Load the Iris dataset using load_iris.

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# ## Prepare data
#
# ### Subtask:
# Separate features (X) and target (y) from the loaded Iris dataset. Understand the target variable (the different Iris species).

# %% [markdown]
# **Reasoning**:
# Extract features and target from the iris dataset and print unique target values and names to understand the classes.

# %%
X = iris.data
y = iris.target

print("Unique target values:", np.unique(y))
print("Target class names:", iris.target_names)
# Out:
# Unique target values: [0 1 2]
# Target class names: ['setosa' 'versicolor' 'virginica']

# %%
class BinaryLogisticRegression:
    def __init__(self, alpha=0.01, n_iterations=1000):
        self.alpha = alpha
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for i in range(self.n_iterations):
            linear_model = X.dot(self.weights) + self.bias
            y_predicted = self.sigmoid(linear_model)

            dw = (1 / n_samples) * X.T.dot(y_predicted - y)
            db = (1 / n_samples) * np.sum(y_predicted - y)

            self.weights -= self.alpha * dw
            self.bias -= self.alpha * db

    def predict(self, X):
        linear_model = X.dot(self.weights) + self.bias
        y_predicted = self.sigmoid(linear_model)
        return y_predicted > 0.5

# %%
binary_models = []
unique_classes = np.unique(y)

for class_label in unique_classes:
    y_binary = (y == class_label).astype(int)
    model = BinaryLogisticRegression()
    binary_models.append(model)

# %%
for i, class_label in enumerate(unique_classes):
    y_binary = (y == class_label).astype(int)
    binary_models[i].fit(X, y_binary)

# %%
class BinaryLogisticRegression:
    def __init__(self, alpha=0.01, n_iterations=1000):
        self.alpha = alpha
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for i in range(self.n_iterations):
            linear_model = X.dot(self.weights) + self.bias
            y_predicted = self.sigmoid(linear_model)

            dw = (1 / n_samples) * X.T.dot(y_predicted - y)
            db = (1 / n_samples) * np.sum(y_predicted - y)

            self.weights -= self.alpha * dw
            self.bias -= self.alpha * db

    def predict_proba(self, X):
        linear_model = X.dot(self.weights) + self.bias
        return self.sigmoid(linear_model)

    def predict(self, X):
        return self.predict_proba(X) > 0.5

binary_models = []
unique_classes = np.unique(y)

for class_label in unique_classes:
    y_binary = (y == class_label).astype(int)
    model = BinaryLogisticRegression()
    model.fit(X, y_binary)
    binary_models.append(model)


def predict_multiclass(binary_models, X):
    n_samples = X.shape[0]
    n_classes = len(binary_models)
    all_probabilities = np.zeros((n_samples, n_classes))

    for i, model in enumerate(binary_models):
        all_probabilities[:, i] = model.predict_proba(X)

    predicted_classes = np.argmax(all_probabilities, axis=1)
    return predicted_classes
multiclass_predictions = predict_multiclass(binary_models, X)
print("Multiclass predictions shape:", multiclass_predictions.shape)
# Out:
# Multiclass predictions shape: (150,)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y, multiclass_predictions)
precision = precision_score(y, multiclass_predictions, average='weighted')
recall = recall_score(y, multiclass_predictions, average='weighted')
f1 = f1_score(y, multiclass_predictions, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (weighted): {precision:.4f}")
print(f"Recall (weighted): {recall:.4f}")
print(f"F1-score (weighted): {f1:.4f}")
# Out:
# Accuracy: 0.8733
# Precision (weighted): 0.9082
# Recall (weighted): 0.8733
# F1-score (weighted): 0.8686
